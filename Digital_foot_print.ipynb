# %%
import matplotlib.pyplot as plt

# %%
d1={
    'Facebook':'https://www.facebook.com/hanu.manu.33',
    'Medium':'https://sidhantha.medium.com/',
    'Hackerrank':'https://www.hackerrank.com/sidh1999',
    'Linkedln':'https://www.linkedin.com/in/sid99/',
    'CoviFight':'https://devpost.com/software/covifight',
    'Youtube':'https://www.youtube.com/channel/UC1otDEJRylVdgbAsZ1ce-Cg/about?view_as=subscriber',
    'Twitter':'https://twitter.com/poddarsidhantha',
    'Devpost':'https://devpost.com/sidhanthapoddar99?',
    'Google':'',
    'CodeChef':'',
    'Instagram':'https://www.instagram.com/sidhanthapoddar/',
   'GitHub':'https://github.com/sidhanthapoddar99',
   'Kaggle':'',
   'Blogger':'https://final-projectx.blogspot.com/',
   'LinkedlnC':[]

}

# %%
d={
    'Facebook':['Medium','Hackerrank','Devpost','Github','Linkedln','Instagram','Twitter','Youtube'],
    'Medium':['Twitter','Linkedln','CoviFight','Facebook','Github','Instagram','Blogger','LinkedlnC','Youtube','Devpost'],
    'Hackerrank':['Github','Linkedln','Medium'],
    'Linkedln':['Medium','LinkedlnC','Github','Devpost'],
    'CoviFight':['Medium','Devpost'],
    'Youtube':['Medium','Hackerrank','Devpost','Github','Linkedln','Instagram','Facebook','Twitter'],
    'Twitter':['Medium'],
    'Devpost':['CoviFight','Medium','Github','Twitter','Linkedln'],
    'Google':['Linkedln','Medium','Hackerrank','Devpost'],
    #'CodeChef':['CodeChef'],
    'Instagram':['Medium'],
   'Github':['Twitter','Medium'],
   #'Kaggle':['Kaggle'],
   'Blogger':['CoviFight','LinkedlnC','Medium','Hackerrank','Devpost','Github','Linkedln','Instagram','Twitter','Facebook'],
   'LinkedlnC':['Linkedln','CoviFight']

}

# %%
for i in d:
  print(i)
tup[:5]
# Out:
# Facebook
# Medium
# Hackerrank
# Linkedln
# CoviFight
# Youtube
# Twitter
# Devpost
# Google
# Instagram
# Github
# Blogger
# LinkedlnC
# [('Facebook', 'Medium'),
#  ('Facebook', 'Hackerrank'),
#  ('Facebook', 'Devpost'),
#  ('Facebook', 'Github'),
#  ('Facebook', 'Linkedln')]

# %%
import networkx as nx 
G = nx.DiGraph() 
# G.add_edges_from([('apple', 1), (1, 7), (2, 1), (2, 2), (2, 3), 
# 				(2, 6), (3, 5), (4, 3), (5, 4), (5, 8), 
# 				(5, 9), (6, 4), (7, 2), (7, 6), (8, 7),(10,10)]) 
tup=[]
for i in d:
  for j in d[i]:
    tup+=[(i,j)]
G.add_edges_from(tup)

# %%
plt.figure(figsize =(30, 12)) 
nx.draw_networkx(G, label = True)

# %%
# getting different graph attributes 
print("Total number of nodes: ", int(G.number_of_nodes())) 
print("Total number of edges: ", int(G.number_of_edges())) 
print("List of all nodes: ", list(G.nodes())) 
print("List of all edges: ", list(G.edges())) 
print("In-degree for all nodes: ", dict(G.in_degree())) 
print("Out degree for all nodes: ", dict(G.out_degree)) 

print("Total number of self-loops: ", int(G.number_of_selfloops())) 
print("List of all nodes with self-loops: ", 
			list(G.nodes_with_selfloops())) 

print("List of all nodes we can go to in a single step from node 2: ", 
												list(G.successors(2))) 

print("List of all nodes from which we can go to node 2 in a single step: ", 
													list(G.predecessors(2)))
